# %%
import sys
import os
import sys
sys.path.append('C:/Users/joeso/Documents/Homework4/meter_Hw4') 

os.chdir("../")

os.getcwd()
# Out:
# 'c:\\'

# %%
preprocessor.load_data("C:/Users/joeso/Desktop/Homework_4/meter_Hw4/data/Meter_A.txt")
# Out:
#          0         1         2         3          4          5         6   \
# 0  0.841499  1.009367  0.993816  8.469805  10.278727  10.037759  8.501365
# 1  0.842250  1.006584  0.996605  7.531891   9.139924   8.951618  7.612213
# 2  0.840723  1.011647  0.998152  6.641699   7.975464   7.857692  6.593117
# 3  0.841119  1.017807  0.996812  5.687524   6.824334   6.689885  5.615428
# 4  0.840358  1.016534  0.996221  5.660385   6.829560   6.675628  5.623977
#
#          7          8          9   ...         27         28         29  \
# 0  8.581726  10.247763  10.058822  ...  32.451173  34.568685  33.082683
# 1  7.623325   9.106345   8.945142  ...  32.428385  34.441732  33.081055
# 2  6.681572   7.964596   7.814698  ...  32.428385  34.275715  33.113605
# 3  5.763315   6.801051   6.686639  ...  32.485350  34.080403  33.170573
# 4  5.736818   6.813453   6.672377  ...  32.503255  34.122720  33.164062
#
#           30         31         32         33         34         35  36
# ...

# %%
from src.data_preprocess import DataPreprocessing

# %%
#sys.path.append('C:/Users/joeso/Desktop/Homework_4/meter_Hw4')
from models.ann_model import ANNModel

# Updating the file path to the correct location
file_path = "C:/Users/joeso/Desktop/Homework_4/meter_Hw4/data/Meter_A.txt"
model = ANNModel(file_path, hidden_layer_sizes=(50, 50), max_iter=500)
model.load_data(file_path)
model.preprocess_data()
model.train()
accuracy = model.test()
print(f"Model Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 9
#       7 model.load_data(file_path)
#       8 #model.preprocess_data()
# ----> 9 model.train()
#      10 accuracy = model.test()
#      11 print(f"Model Accuracy: {accuracy:.4f}")
#
# AttributeError: 'ANNModel' object has no attribute 'train'
