# %%
import pandas as pd

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv('../data/Meter_A.txt', sep='\t', header=None).dropna()
data.sample(10)
# Out:
#           0         1         2         3         4         5         6   \
# 9   0.835900  1.014731  0.997580  4.744331  5.749815  5.625256  4.729561
# 18  0.837927  1.005684  0.995000  7.453149  9.109174  8.913713  7.560133
# 67  0.834050  1.019825  1.001583  1.916449  2.303998  2.258933  1.884156
# 53  0.843066  1.011790  0.996410  5.635805  6.815762  6.679369  5.673658
# 3   0.841119  1.017807  0.996812  5.687524  6.824334  6.689885  5.615428
# 38  0.809409  1.015500  0.995497  5.459944  6.841937  6.697505  5.432878
# 30  0.831790  1.022042  0.998620  2.856345  3.446030  3.369303  2.797675
# 55  0.842534  1.013867  0.998813  5.683765  6.791123  6.694044  5.635394
# 13  0.836617  1.017294  0.999492  2.870597  3.453463  3.386483  2.841594
# 8   0.841672  1.008904  0.994212  5.623128  6.815121  6.681624  5.680006
#
#           7         8         9   ...         27         28         29  \
# 9   4.810332  5.722404  5.642602  ...  32.534182  33.979493  33.204753
# ...

# %%
# Out:
#   Cell In[8], line 1
#     data.36.value_counts()
#         ^
# SyntaxError: invalid syntax

# %%
data = data.to_numpy()

data
# Out:
# array([[ 0.84149871,  1.00936653,  0.99381601, ..., 35.174155  ,
#         32.72949   ,  1.        ],
#        [ 0.84225022,  1.00658369,  0.99660521, ..., 34.847005  ,
#         32.73112167,  1.        ],
#        [ 0.84072314,  1.01164657,  0.99815174, ..., 34.68912833,
#         32.77181   ,  1.        ],
#        ...,
#        [ 0.79347112,  1.00955964,  1.00111012, ..., 33.82487   ,
#         33.02083167,  2.        ],
#        [ 0.79672987,  1.01057037,  0.99902897, ..., 33.81673167,
#         33.01106667,  2.        ],
#        [ 0.79019427,  1.00419541,  0.99553749, ..., 33.66862167,
#         33.11848833,  2.        ]])

# %%
def load_data(path):
    data = pd.read_csv(path, sep='\t', header=None).dropna()
    print(data.head())
    data = data.to_numpy()
    return data

# %%
data = load_data('../data/Meter_A.txt')
# Out:
#          0         1         2         3          4          5         6   \
# 0  0.841499  1.009367  0.993816  8.469805  10.278727  10.037759  8.501365
# 1  0.842250  1.006584  0.996605  7.531891   9.139924   8.951618  7.612213
# 2  0.840723  1.011647  0.998152  6.641699   7.975464   7.857692  6.593117
# 3  0.841119  1.017807  0.996812  5.687524   6.824334   6.689885  5.615428
# 4  0.840358  1.016534  0.996221  5.660385   6.829560   6.675628  5.623977
#
#          7          8          9   ...         27         28         29  \
# 0  8.581726  10.247763  10.058822  ...  32.451173  34.568685  33.082683
# 1  7.623325   9.106345   8.945142  ...  32.428385  34.441732  33.081055
# 2  6.681572   7.964596   7.814698  ...  32.428385  34.275715  33.113605
# 3  5.763315   6.801051   6.686639  ...  32.485350  34.080403  33.170573
# 4  5.736818   6.813453   6.672377  ...  32.503255  34.122720  33.164062
#
#           30         31         32         33         34         35  36
# ...

# %%
data.shape
# Out:
# (87, 37)

# %% [markdown]
# ## We can create our parent class data_preprocess.py based on this code
