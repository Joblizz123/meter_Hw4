# %%
import sys
sys.path.append('C:/Users/joeso/Documents/Homework4/meter_Hw4')  # Ensure the correct path is added

from models.ann_model import ANNModel

from models.ann_model import ANNModel



configs = [
    ((50, 50), 0.01, 500),
    ((100,), 0.001, 200),
    ((30, 30, 30), 0.005, 1000),
]

for config in configs:
    hidden_layers, learning_rate, max_iter = config
    model = ANNModel(hidden_layer_sizes=hidden_layers, learning_rate=learning_rate, max_iter=max_iter)
    model.load_data("data/dataset.csv")
    model.preprocess_data()
    model.train()
    accuracy = model.test()
    print(f"Config: {config}, Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 4
#       1 import sys
#       2 sys.path.append('C:/Users/joeso/Documents/Homework4/meter_Hw4')  # Ensure the correct path is added
# ----> 4 from models.ann_model import ANNModel
#       6 from models.ann_model import ANNModel
#      10 configs = [
#      11     ((50, 50), 0.01, 500),
#      12     ((100,), 0.001, 200),
#      13     ((30, 30, 30), 0.005, 1000),
#      14 ]
#
# File C:\Users/joeso/Documents/Homework4/meter_Hw4\models\ann_model.py:52
#      50 from sklearn.neural_network import MLPClassifier
#      51 from sklearn.metrics import accuracy_score
# ---> 52 from base_ann import BaseANN  # Importing the BaseANN class
#      54 class ANNModel(BaseANN):
#      55     def __init__(self, file_path, hidden_layer_sizes=(100,), learning_rate_init=0.01, max_iter=200):
#
# ModuleNotFoundError: No module named 'base_ann'

# %%
from models.ann_model import ANNModel

try:
    except ImportError as e:
        print(f"Error importing ANNModel: {e}")

configs = [
    ((50, 50), 0.01, 500),
    ((100,), 0.001, 200),
    ((30, 30, 30), 0.005, 1000),
]

for config in configs:
    hidden_layers, learning_rate, max_iter = config
    model = ANNModel(hidden_layer_sizes=hidden_layers, learning_rate=learning_rate, max_iter=max_iter)
    model.load_data("data/dataset.csv")
    model.preprocess_data()
    model.train()
    accuracy = model.test()
    print(f"Config: {config}, Accuracy: {accuracy:.4f}")
# Out:
#   Cell In[6], line 4
#     except ImportError as e:
#     ^
# SyntaxError: invalid syntax
